# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.load(r'D:\Work\gdp-hmm-model-docker\docker\src\data_demo\0617-259694+imrt+MOS_33896.npz', allow_pickle=True)

# %%
a = dict(a['arr_0'].item())

# %%
dose = a['dose'] * a['dose_scale']

# %%
b = np.load(r'D:\Work\gdp-hmm-model-docker\docker\0617-259694+imrt+MOS_33896_pred.npy')

# %%
dose.shape
# Out:
# (96, 100, 151)

# %%
b.shape
# Out:
# (96, 100, 151)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 8))
ax[0].imshow(dose[50], vmin=0, vmax=70)
ax[1].imshow(b[50], vmin=0, vmax=70)
